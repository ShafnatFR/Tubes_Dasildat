# %%
from mpl_toolkits.axisartist.axislines import SubplotZero
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from numpy import unique
from pandas import read_csv
import seaborn as sns
sns.set(style='ticks')
import matplotlib.cm as cm
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report
from sklearn.svm import SVC
from sklearn.impute import SimpleImputer
from imblearn.over_sampling import SMOTE

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# %cd /content/drive/My Drive/Tubes_Dasildat
# !ls
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/Tubes_Dasildat
# Algoritma_SVM.sav  diabetes.csv  models

# %% [markdown]
# # Load data

# %%
df = pd.DataFrame()
data = pd.read_csv('/content/drive/My Drive/Tubes_Dasildat/diabetes.csv')
df = pd.concat([df,data])
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
plt.hist(df['Outcome'])
plt.show()

# %% [markdown]
# # Memisahkan Label dan Feature

# %%
X = df.drop('Outcome', axis=1)
y = df['Outcome']

# %% [markdown]
# # Membagi Data

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,
    random_state=0,
    stratify=y
)
print(f"Train-test split: train={len(X_train)}, test={len(X_test)}")
# Out:
# Train-test split: train=614, test=154

# %% [markdown]
# # Preprocessing

# %%
from sklearn.preprocessing import StandardScaler
import pandas as pd

scaler = StandardScaler()

X_train_scaled = pd.DataFrame(
    scaler.fit_transform(X_train),
    columns=X.columns
)

X_test_scaled = pd.DataFrame(
    scaler.transform(X_test),
    columns=X.columns
)

# %% [markdown]
# # Imbalance

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state=0)
X_smote_resampled, y_smote_resampled = smote.fit_resample(X_train_scaled, y_train)

X_smote = pd.DataFrame(X_smote_resampled, columns=X.columns)
y_smote = pd.DataFrame(y_smote_resampled, columns=[y.name])

df_balanced = pd.concat([X_smote, y_smote], axis=1)
df_balanced.head()
plt.hist(df_balanced['Outcome'])
plt.show()

# %% [markdown]
# # HPO Algoritma SVM

# %%
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV

y_smote = y_smote.squeeze()

param_grid = {
    'C': [0.1, 1, 10, 50, 100],
    'gamma': ['scale', 0.03, 0.1, 0.01, 0.001, 0.0001],
    'kernel': ['rbf'],
}

classifier_svm = GridSearchCV(
    SVC(),
    param_grid,
    scoring='recall_macro',
    cv=10,
    refit=True,
    verbose=4,
    n_jobs=-1
)

classifier_svm.fit(X_smote, y_smote)

print('parameter terbaik:',classifier_svm.best_params_)
print(classifier_svm.best_estimator_)
# Out:
# Fitting 10 folds for each of 30 candidates, totalling 300 fits
# parameter terbaik: {'C': 50, 'gamma': 0.1, 'kernel': 'rbf'}
# SVC(C=50, gamma=0.1)

# %% [markdown]
# # Confusion Matrix

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

pred_knn = classifier_svm.predict(X_test_scaled)

print("Accuracy:", accuracy_score(y_test, pred_knn))
print(classification_report(y_test, pred_knn))

cm = confusion_matrix(y_test, pred_knn)
disp = ConfusionMatrixDisplay(cm)
disp.plot()
plt.show()
# Out:
# Accuracy: 0.7987012987012987
#               precision    recall  f1-score   support
#
#            0       0.83      0.87      0.85       100
#            1       0.73      0.67      0.70        54
#
#     accuracy                           0.80       154
#    macro avg       0.78      0.77      0.77       154
# weighted avg       0.80      0.80      0.80       154

# %% [markdown]
# # Save Data

# %%
from google.colab import files
import joblib

try:
    # Save the trained SVM model to the specified path
    joblib.dump(classifier_svm.best_estimator_, '/content/Tubes_Dasildat_SVM.sav')

    # Now download the file
    files.download('/content/Tubes_Dasildat_SVM.sav')
    # files.download('/content/Tubes_Dasildat_KNN.sav')
    # files.download('/content/Tubes_Dasildat_DecisionTree.sav')
    # files.download('/content/Tubes_Dasildat_NN.sav')
except NameError:
    print("Error: 'classifier_svm' is not defined. Please ensure the 'HPO Algoritma SVM' cell (HMyOOwQDtO7u) has been executed to define it.")
# Out:
# Error: 'classifier_svm' is not defined. Please ensure the 'HPO Algoritma SVM' cell (HMyOOwQDtO7u) has been executed to define it.

# %%
import joblib

scaler_filename = '/content/drive/My Drive/Tubes_Dasildat/Scaler.sav'
joblib.dump(scaler, scaler_filename)
print(f"Scaler saved to {scaler_filename}")
# Out:
# Scaler saved to /content/drive/My Drive/Tubes_Dasildat/Scaler.sav
